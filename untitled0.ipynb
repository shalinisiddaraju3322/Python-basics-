# %% [markdown]
# <a href="https://colab.research.google.com/github/shalinisiddaraju3322/Python-basics-/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("shalini")
# Out:
# shalini

# %%
name="shalini"
year="2008"

print("Hello",name)
print(year)
# Out:
# Hello shalini
# 2008

# %%
name="shalini"
year="2008"

print(name+year)
# Out:
# shalini2008

# %%
a=10
b=5
sum=a+b
sub=a-b
mul=a*b
div=a/b
print("sum",sum)
print("sub",sub)
print("mul",mul)
print("div",div)
# Out:
# sum 15
# sub 5
# mul 50
# div 2.0

# %%
a=input("Enter your name:")
b=input("Enter your branch:")

print("hello",a)
print(b)
# Out:
# Enter your name:Shalini
# Enter your branch:CSE
# hello Shalini
# CSE

# %%
A=int(input("Enter the value of a:"))
B=int(input("Enter the value of b:"))
sum=A+B
sub=A-B
mul=A*B
div=A/B

print("sum",sum)
print("sub",sub)
print("mul",mul)
print("div",div)
# Out:
# Enter the value of a:10
# Enter the value of b:2
# sum 12
# sub 8
# mul 20
# div 5.0

# %%
age=int(input("Enter your age:"))

if age>=18:
   print("you can vote")

else:
     print("come again next year")
# Out:
# Enter your age:3
# come again next year

# %%
for i in range(1,7):
    print(2*i,end=" ")
print()
# Out:
# 2 4 6 8 10 12

# %%
marks=int(input("Enter your marks:"))

if marks>50:
   print("you are promoted")
else:
   print("come again next year")
# Out:
# Enter your marks:22
# come again next year

# %%
def greet():
    print("Hello world")

greet()
# Out:
# Hello world

# %%
def greet (name):
    print("Hello 👋🏻",name)

greet("shalini")
greet("siddraju")
# Out:
# Hello 👋🏻 shalini
# Hello 👋🏻 siddraju

# %%
def add(a,b):
    return a+b

result = add(5,3)
print(result)
# Out:
# 8
